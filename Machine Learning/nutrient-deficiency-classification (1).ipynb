# %%
pip install -q tflite-model-maker
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

import tensorflow as tf
assert tf.__version__.startswith('2')

from tflite_model_maker import configs
from tflite_model_maker import ExportFormat
from tflite_model_maker import image_classifier
from tflite_model_maker import ImageClassifierDataLoader
from tflite_model_maker import model_spec

import matplotlib.pyplot as plt

# %%
data = ImageClassifierDataLoader.from_folder('../input/nutrientdeficiencysymptomsinrice/rice_plant_lacks_nutrients')
train_data, test_data = data.split(0.8)

# %%
model = image_classifier.create(train_data)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# hub_keras_layer_v1v2_1 (HubK (None, 1280)              3413024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1280)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 3843
# =================================================================
# Total params: 3,416,867
# Trainable params: 3,843
# Non-trainable params: 3,413,024
# _________________________________________________________________
# None
# Epoch 1/5
# 28/28 [==============================] - 43s 1s/step - loss: 1.0962 - accuracy: 0.4738
# Epoch 2/5
# 28/28 [==============================] - 40s 1s/step - loss: 0.5628 - accuracy: 0.8556
# Epoch 3/5
# 28/28 [==============================] - 40s 1s/step - loss: 0.5255 - accuracy: 0.8766
# Epoch 4/5
# 28/28 [==============================] - 42s 1s/step - loss: 0.4902 - accuracy: 0.9008
# Epoch 5/5
# 28/28 [==============================] - 40s 1s/step - loss: 0.4582 - accuracy: 0.9235

# %%
loss, accuracy = model.evaluate(test_data)
# Out:
# 8/8 [==============================] - 24s 1s/step - loss: 0.4518 - accuracy: 0.9310

# %%
model.export(export_dir='./', with_metadata=True)
